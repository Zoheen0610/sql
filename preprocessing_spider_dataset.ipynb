# %% [markdown]
# <a href="https://colab.research.google.com/github/sharik31/SQL-Generator/blob/main/preprocessing_spider_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  Convert train_spider.json to CSV with db_id, input, and output

# %%
import json
import csv

with open('/content/train_spider.json') as f:
    train_data = json.load(f)

with open('spider_train_with_dbid.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=['db_id', 'input', 'output'])
    writer.writeheader()

    for item in train_data:
        db_id = item['db_id']
        question = item['question']
        sql = item['query']
        input_text = f"translate to SQL: {question}"
        writer.writerow({'db_id': db_id, 'input': input_text, 'output': sql})

print("Saved spider_train_with_dbid.csv with columns: db_id, input, output")
# Out:
# Saved spider_train_with_dbid.csv with columns: db_id, input, output

# %%
import pandas as pd
df=pd.read_csv('/content/spider_train_with_dbid.csv')

# %%
df.head()
# Out:
#                    db_id                                              input  \
# 0  department_management  translate to SQL: How many heads of the depart...
# 1  department_management  translate to SQL: List the name, born state an...
# 2  department_management  translate to SQL: List the creation year, name...
# 3  department_management  translate to SQL: What are the maximum and min...
# 4  department_management  translate to SQL: What is the average number o...
#
#                                               output
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...

# %% [markdown]
# ## Add Corresponding Table Schema from table.json as Separate Column

# %%
import json
import pandas as pd

df = pd.read_csv('spider_train_with_dbid.csv')

with open('tables.json') as f:
    schemas = json.load(f)

schema_map = {schema['db_id']: schema for schema in schemas}

def serialize_schema(schema):
    table_names = schema.get('table_names_original', schema.get('table_names', []))
    columns = schema.get('column_names_original', schema.get('column_names', []))
    tables = {i: [] for i in range(len(table_names))}
    for col in columns:
        idx, col_name = col
        if idx != -1 and idx < len(table_names):
            tables[idx].append(col_name)
    serialized = []
    for idx, table_name in enumerate(table_names):
        cols = ", ".join(tables[idx])
        serialized.append(f"Table {table_name} ({cols})")
    return " ".join(serialized)

def get_schema_text(row):
    db_id = row['db_id']
    if db_id in schema_map:
        return serialize_schema(schema_map[db_id])
    else:
        return ""

df['schema'] = df.apply(get_schema_text, axis=1)

df.to_csv('spider_train_with_separate_schema_column.csv', index=False)

print("CSV with separate 'schema' column saved as 'spider_train_with_separate_schema_column.csv'")
# Out:
# CSV with separate 'schema' column saved as 'spider_train_with_separate_schema_column.csv'

# %%
df.head()
# Out:
#                    db_id                                              input  \
# 0  department_management  translate to SQL: How many heads of the depart...
# 1  department_management  translate to SQL: List the name, born state an...
# 2  department_management  translate to SQL: List the creation year, name...
# 3  department_management  translate to SQL: What are the maximum and min...
# 4  department_management  translate to SQL: What is the average number o...
#
#                                               output  \
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...
#
#                                               schema
# 0  Table department (Department_ID, Name, Creatio...
# 1  Table department (Department_ID, Name, Creatio...
# 2  Table department (Department_ID, Name, Creatio...
# 3  Table department (Department_ID, Name, Creatio...
# 4  Table department (Department_ID, Name, Creatio...

# %%
df.sample(n=10)
# Out:
#                     db_id                                              input  \
# 1766              gymnast  translate to SQL: List the names of gymnasts i...
# 4711     department_store  translate to SQL: What are the product id and ...
# 3250            college_1  translate to SQL: What is the total number of ...
# 5003             soccer_2  translate to SQL: What are the names and hours...
# 439             allergy_1    translate to SQL: How many allergies are there?
# 2374                csu_1  translate to SQL: What is the number of facult...
# 4222  cre_Doc_Tracking_DB  translate to SQL: Show the location code, the ...
# 2003          gas_company  translate to SQL: Show all main industry for a...
# 2308          perpetrator  translate to SQL: What are the names of people...
# 2797             election  translate to SQL: Which parties did not have a...
#
#                                                  output  \
# 1766  SELECT T2.Name FROM gymnast AS T1 JOIN people ...
# 4711  SELECT product_id ,  product_type_code FROM pr...
# 3250  SELECT count(*) FROM professor WHERE prof_high...
# 5003  SELECT T1.pName ,  T1.HS FROM player AS T1 JOI...
# 439    SELECT count(DISTINCT allergy) FROM Allergy_type
# 2374  SELECT faculty FROM faculty AS T1 JOIN campuse...
# 4222  SELECT location_code ,  date_in_location_from ...
# 2003         SELECT DISTINCT main_industry FROM company
# 2308        SELECT Name FROM People ORDER BY Height ASC
# 2797  SELECT Party FROM party WHERE Party_ID NOT IN ...
#
#                                                  schema
# 1766  Table gymnast (Gymnast_ID, Floor_Exercise_Poin...
# 4711  Table Addresses (address_id, address_details) ...
# 3250  Table CLASS (CLASS_CODE, CRS_CODE, CLASS_SECTI...
# 5003  Table College (cName, state, enr) Table Player...
# 439   Table Allergy_Type (Allergy, AllergyType) Tabl...
# 2374  Table Campuses (Id, Campus, Location, County, ...
# 4222  Table Ref_Document_Types (Document_Type_Code, ...
# 2003  Table company (Company_ID, Rank, Company, Head...
# 2308  Table perpetrator (Perpetrator_ID, People_ID, ...
# 2797  Table county (County_Id, County_name, Populati...

# %%
print(len(df))
# Out:
# 7000

# %%
print(df.isnull().sum())
# Out:
# db_id     0
# input     0
# output    0
# schema    0
# dtype: int64

# %% [markdown]
# ## Preprocessing DevSet

# %%
with open('/content/dev.json') as f:
    train_data = json.load(f)

with open('spider_val_with_dbid.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=['db_id', 'input', 'output'])
    writer.writeheader()

    for item in train_data:
        db_id = item['db_id']
        question = item['question']
        sql = item['query']
        input_text = f"translate to SQL: {question}"
        writer.writerow({'db_id': db_id, 'input': input_text, 'output': sql})

print("Saved spider_val_with_dbid.csv with columns: db_id, input, output")
# Out:
# Saved spider_val_with_dbid.csv with columns: db_id, input, output

# %%
import pandas as pd
df=pd.read_csv('/content/spider_val_with_dbid.csv')

# %%
df.head()
# Out:
#             db_id                                              input  \
# 0  concert_singer     translate to SQL: How many singers do we have?
# 1  concert_singer  translate to SQL: What is the total number of ...
# 2  concert_singer  translate to SQL: Show name, country, age for ...
# 3  concert_singer  translate to SQL: What are the names, countrie...
# 4  concert_singer  translate to SQL: What is the average, minimum...
#
#                                               output
# 0                        SELECT count(*) FROM singer
# 1                        SELECT count(*) FROM singer
# 2  SELECT name ,  country ,  age FROM singer ORDE...
# 3  SELECT name ,  country ,  age FROM singer ORDE...
# 4  SELECT avg(age) ,  min(age) ,  max(age) FROM s...

# %%
print(len(df))
# Out:
# 1034

# %%
df = pd.read_csv('spider_val_with_dbid.csv')

with open('tables.json') as f:
    schemas = json.load(f)

schema_map = {schema['db_id']: schema for schema in schemas}

def serialize_schema(schema):
    table_names = schema.get('table_names_original', schema.get('table_names', []))
    columns = schema.get('column_names_original', schema.get('column_names', []))
    tables = {i: [] for i in range(len(table_names))}
    for col in columns:
        idx, col_name = col
        if idx != -1 and idx < len(table_names):
            tables[idx].append(col_name)
    serialized = []
    for idx, table_name in enumerate(table_names):
        cols = ", ".join(tables[idx])
        serialized.append(f"Table {table_name} ({cols})")
    return " ".join(serialized)

def get_schema_text(row):
    db_id = row['db_id']
    if db_id in schema_map:
        return serialize_schema(schema_map[db_id])
    else:
        return ""

df['schema'] = df.apply(get_schema_text, axis=1)

df.to_csv('spider_val_with_separate_schema_column.csv', index=False)

print("CSV with separate 'schema' column saved as 'spider_val_with_separate_schema_column.csv'")
# Out:
# CSV with separate 'schema' column saved as 'spider_val_with_separate_schema_column.csv'

# %%
df.head()
# Out:
#             db_id                                              input  \
# 0  concert_singer     translate to SQL: How many singers do we have?
# 1  concert_singer  translate to SQL: What is the total number of ...
# 2  concert_singer  translate to SQL: Show name, country, age for ...
# 3  concert_singer  translate to SQL: What are the names, countrie...
# 4  concert_singer  translate to SQL: What is the average, minimum...
#
#                                               output  \
# 0                        SELECT count(*) FROM singer
# 1                        SELECT count(*) FROM singer
# 2  SELECT name ,  country ,  age FROM singer ORDE...
# 3  SELECT name ,  country ,  age FROM singer ORDE...
# 4  SELECT avg(age) ,  min(age) ,  max(age) FROM s...
#
#                                               schema
# 0  Table stadium (Stadium_ID, Location, Name, Cap...
# 1  Table stadium (Stadium_ID, Location, Name, Cap...
# 2  Table stadium (Stadium_ID, Location, Name, Cap...
# 3  Table stadium (Stadium_ID, Location, Name, Cap...
# 4  Table stadium (Stadium_ID, Location, Name, Cap...

# %%
print(len(df))
# Out:
# 1034

# %%
print(df.isnull().sum())
# Out:
# db_id     0
# input     0
# output    0
# schema    0
# dtype: int64
